# %% [markdown]
# # 2. Get & Set Human Entity Rule

# %% [markdown]
# ## Get Human Entity Rule

# %%
import pandas as pd

# %%
# Import dataset
entityDFJuz3 = pd.read_excel('./Dataset/human-entity-juz-3.xlsx')
pd.set_option('display.max_rows', 999999)

# %%
# Import dataset
entityDF10Juz = pd.read_excel('./Dataset/human-entity-10-juz.xlsx')
pd.set_option('display.max_rows', 999999)

# %%
def findHumanEntityPatterns(file):
    
    tempPatterns = [[]]
    finalPatterns = []
    currentTag = 0
    opentagCount = 0
    df = pd.DataFrame({'pattern': []})
    
    for i in range(len(file)):

        closetags = [char for char in str(file.at[i, "closetag"])]
        opentags = [char for char in str(file.at[i, "opentag"])]

        for j in range(len(opentags)):
            if opentags[j] == '(':
                opentagCount += 1

        if opentagCount > 0:
            tempPatterns[currentTag].append(file.at[i, "tag"])

        for k in range(len(closetags)):
            if closetags[k] == ')':
                if opentagCount == 1:
                    toInput = (str(tempPatterns[currentTag]))
                    df = df.append({'pattern' : toInput}, ignore_index=True)
                    finalPatterns.append(tempPatterns[currentTag])
                    currentTag += 1
                    tempPatterns.append([])
                opentagCount -= 1
                
    if tempPatterns[len(tempPatterns)-1] == []:
        del tempPatterns[len(tempPatterns)-1]

    
    tempPatterns = set(tuple(element) for element in tempPatterns)
    tempPatterns = [list(t) for t in set(tuple(element) for element in tempPatterns)]    
        
    return tempPatterns
#     return df

# %%
patternsJuz3 = findHumanEntityPatterns(entityDFJuz3)
patterns10Juz = findHumanEntityPatterns(entityDF10Juz)

# %% [markdown]
# Use return df for good looking data

# %% [markdown]
# Juz 3

# %%
print (len(patternsJuz3))
patternsJuz3
# Out:
# 84
#                                               pattern
# 0                                        ['REL', 'V']
# 1                                   ['PN', 'N', 'PN']
# 2                           ['REL', 'P', 'N', 'PRON']
# 3                                        ['REL', 'V']
# 4                                        ['REL', 'V']
# 5                                ['REL', 'V', 'PRON']
# 6                                       ['N', 'PRON']
# 7                                               ['N']
# 8   ['COND', 'V', 'P', 'DET', 'N', 'CONJ', 'V', 'P...
# 9                                ['REL', 'V', 'PRON']
# 10                               ['REL', 'V', 'PRON']
# 11                                 ['REL', 'V', 'PN']
# 12                                             ['PN']
# 13                                             ['PN']
# 14                                       ['REL', 'V']
# 15                                ['N', 'DET', 'ADJ']
# 16                             ['REL', 'V', 'P', 'N']
# 17                                              ['N']
# 18                                             ['PN']
# 19                                              ['N']
# 20  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'PN']
# 21                                       ['REL', 'V']
# 22  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'PN']
# 23                               ['REL', 'V', 'PRON']
# 24                          ['REL', 'V', 'N', 'PRON']
# 25                                              ['N']
# 26                                              ['N']
# 27                                            ['ADJ']
# 28  ['REL', 'V', 'PRON', 'N', 'PRON', 'N', 'N', 'PN']
# 29                               ['REL', 'V', 'PRON']
# 30                                       ['REL', 'V']
# 31                          ['COND', 'V', 'DET', 'N']
# 32                                  ['N', 'DET', 'N']
# 33                                       ['DET', 'N']
# 34                                              ['N']
# 35                                              ['N']
# 36                                       ['REL', 'V']
# 37                                              ['N']
# 38               ['REL', 'V', 'PRON', 'P', 'N', 'PN']
# 39                                              ['N']
# 40                                              ['N']
# 41                                              ['N']
# 42  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'DET', ...
# 43                   ['REL', 'V', 'PRON', 'DET', 'N']
# 44                               ['REL', 'V', 'PRON']
# 45                              ['COND', 'V', 'PRON']
# 46                                      ['COND', 'V']
# 47                          ['N', 'DET', 'N', 'PRON']
# 48  ['REL', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DET...
# 49                               ['REL', 'V', 'PRON']
# 50                                              ['N']
# 51                               ['REL', 'V', 'PRON']
# 52                   ['REL', 'P', 'PRON', 'DET', 'N']
# 53                   ['REL', 'P', 'PRON', 'DET', 'N']
# 54                               ['REL', 'V', 'PRON']
# 55                                              ['N']
# 56                                              ['N']
# 57                                              ['N']
# 58                                              ['N']
# 59                                       ['REL', 'V']
# 60                              ['COND', 'V', 'PRON']
# 61                                       ['REL', 'V']
# 62                                              ['N']
# 63                                              ['N']
# 64                                              ['N']
# 65                                      ['N', 'PRON']
# 66                                              ['N']
# 67                          ['REL', 'P', 'N', 'PRON']
# 68                                              ['N']
# 69                                            ['ADJ']
# 70                                              ['N']
# 71                               ['REL', 'V', 'PRON']
# 72                    ['COND', 'P', 'N', 'PRON', 'N']
# 73                                  ['N', 'DET', 'N']
# 74                                              ['N']
# 75                               ['REL', 'V', 'PRON']
# 76                                      ['N', 'PRON']
# 77                                        ['N', 'PN']
# 78                          ['REL', 'P', 'N', 'PRON']
# 79                               ['REL', 'V', 'PRON']
# 80                                       ['REL', 'V']
# 81                                  ['N', 'DET', 'N']
# 82                          ['N', 'CONJ', 'DET', 'N']
# 83                               ['REL', 'V', 'PRON']

# %%
patternsJuz3 = patternsJuz3.drop_duplicates(subset=None, keep='first', inplace=False)
print(len(patternsJuz3))
patternsJuz3
# Out:
# 29
#                                               pattern
# 0                                        ['REL', 'V']
# 1                                   ['PN', 'N', 'PN']
# 2                           ['REL', 'P', 'N', 'PRON']
# 5                                ['REL', 'V', 'PRON']
# 6                                       ['N', 'PRON']
# 7                                               ['N']
# 8   ['COND', 'V', 'P', 'DET', 'N', 'CONJ', 'V', 'P...
# 11                                 ['REL', 'V', 'PN']
# 12                                             ['PN']
# 15                                ['N', 'DET', 'ADJ']
# 16                             ['REL', 'V', 'P', 'N']
# 20  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'PN']
# 24                          ['REL', 'V', 'N', 'PRON']
# 27                                            ['ADJ']
# 28  ['REL', 'V', 'PRON', 'N', 'PRON', 'N', 'N', 'PN']
# 31                          ['COND', 'V', 'DET', 'N']
# 32                                  ['N', 'DET', 'N']
# 33                                       ['DET', 'N']
# 38               ['REL', 'V', 'PRON', 'P', 'N', 'PN']
# 42  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'DET', ...
# 43                   ['REL', 'V', 'PRON', 'DET', 'N']
# 45                              ['COND', 'V', 'PRON']
# 46                                      ['COND', 'V']
# 47                          ['N', 'DET', 'N', 'PRON']
# 48  ['REL', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DET...
# 52                   ['REL', 'P', 'PRON', 'DET', 'N']
# 72                    ['COND', 'P', 'N', 'PRON', 'N']
# 77                                        ['N', 'PN']
# 82                          ['N', 'CONJ', 'DET', 'N']

# %% [markdown]
# 10 Juz

# %%
print (len(patterns10Juz))
patterns10Juz
# Out:
# 441
#                                                pattern
# 0                                                ['N']
# 1                                                ['N']
# 2                                              ['ADJ']
# 3                                                ['N']
# 4                                                ['N']
# 5                                         ['DET', 'N']
# 6                                                ['N']
# 7                                                ['N']
# 8                                         ['REL', 'V']
# 9                                                ['N']
# 10                                  ['REL', 'V', 'PN']
# 11                    ['REL', 'V', 'PRON', 'DET', 'N']
# 12                    ['REL', 'V', 'PRON', 'DET', 'N']
# 13                                               ['N']
# 14            ['REL', 'V', 'PRON', 'PRON', 'DET', 'N']
# 15                                       ['N', 'PRON']
# 16                                               ['N']
# 17                                               ['N']
# 18                                ['REL', 'V', 'PRON']
# 19                                               ['N']
# 20                                ['REL', 'V', 'PRON']
# 21                                        ['DET', 'N']
# 22                   ['REL', 'V', 'P', 'N', 'PN', 'N']
# 23                                               ['N']
# 24                      ['REL', 'T', 'V', 'PRON', 'N']
# 25                                               ['N']
# 26              ['COND', 'V', 'DET', 'N', 'CONJ', 'V']
# 27                                ['REL', 'V', 'PRON']
# 28                                               ['N']
# 29                                               ['N']
# 30                                ['REL', 'V', 'PRON']
# 31                                ['REL', 'V', 'PRON']
# 32                                               ['N']
# 33                                               ['N']
# 34                                        ['REL', 'V']
# 35                                ['REL', 'V', 'PRON']
# 36                                ['REL', 'V', 'PRON']
# 37                                ['REL', 'V', 'PRON']
# 38                                ['REL', 'V', 'PRON']
# 39                                ['REL', 'V', 'PRON']
# 40                         ['P', 'N', 'P', 'DET', 'N']
# 41                                               ['N']
# 42                                       ['N', 'PRON']
# 43                                       ['N', 'PRON']
# 44                                ['REL', 'V', 'PRON']
# 45                                        ['REL', 'V']
# 46                                               ['N']
# 47                                               ['N']
# 48                                               ['N']
# 49                                ['REL', 'V', 'PRON']
# 50                                       ['COND', 'V']
# 51                                ['REL', 'V', 'PRON']
# 52   ['REL', 'V', 'PRON', 'DET', 'N', 'P', 'DET', 'N']
# 53               ['REL', 'V', 'PRON', 'P', 'DET', 'N']
# 54                                        ['REL', 'V']
# 55                                               ['N']
# 56                                   ['N', 'DET', 'N']
# 57                                               ['N']
# 58                                               ['N']
# 59                                   ['N', 'DET', 'N']
# 60                                               ['N']
# 61                                   ['V', 'DET', 'N']
# 62                                   ['V', 'DET', 'N']
# 63                                               ['N']
# 64                                               ['N']
# 65                                        ['REL', 'V']
# 66                                               ['N']
# 67                                ['REL', 'V', 'PRON']
# 68                                               ['N']
# 69                                               ['N']
# 70                                               ['N']
# 71                                               ['N']
# 72                                               ['N']
# 73                                       ['COND', 'V']
# 74                                       ['N', 'PRON']
# 75                                       ['COND', 'V']
# 76                                       ['N', 'PRON']
# 77                                               ['N']
# 78                                               ['N']
# 79                                               ['N']
# 80                               ['COND', 'V', 'PRON']
# 81                                ['REL', 'V', 'PRON']
# 82                                       ['COND', 'V']
# 83                                               ['N']
# 84                                ['REL', 'V', 'PRON']
# 85                           ['REL', 'P', 'N', 'PRON']
# 86                     ['COND', 'V', 'P', 'PRON', 'N']
# 87                        ['REL', 'V', 'PRON', 'PRON']
# 88                                  ['COND', 'V', 'N']
# 89                                               ['N']
# 90                          ['COND', 'V', 'P', 'PRON']
# 91                                  ['COND', 'V', 'N']
# 92                                               ['N']
# 93                                       ['N', 'PRON']
# 94                                       ['N', 'PRON']
# 95                               ['V', 'PRON', 'PRON']
# 96                                               ['N']
# 97                                               ['N']
# 98                                               ['N']
# 99                                               ['N']
# 100                                              ['N']
# 101                                       ['REL', 'V']
# 102                       ['REL', 'V', 'PRON', 'PRON']
# 103                                              ['N']
# 104                                              ['N']
# 105                                              ['N']
# 106                                              ['N']
# 107                                              ['N']
# 108  ['REL', 'NEG', 'V', 'N', 'PRON', 'N', 'DET', '...
# 109                                  ['N', 'DET', 'N']
# 110                                              ['N']
# 111                                              ['N']
# 112                                      ['N', 'PRON']
# 113                                              ['N']
# 114                                            ['REL']
# 115                                      ['COND', 'V']
# 116                                       ['REL', 'V']
# 117                                              ['N']
# 118                               ['REL', 'V', 'PRON']
# 119                                              ['N']
# 120                                              ['N']
# 121                          ['REL', 'V', 'N', 'PRON']
# 122                                        ['N', 'PN']
# 123                                      ['COND', 'V']
# 124                               ['REL', 'V', 'PRON']
# 125                               ['REL', 'V', 'PRON']
# 126                               ['REL', 'V', 'PRON']
# 127                                       ['REL', 'V']
# 128                                              ['N']
# 129                                              ['N']
# 130                                              ['N']
# 131                                              ['N']
# 132                       ['REL', 'V', 'PRON', 'PRON']
# 133                               ['REL', 'V', 'PRON']
# 134                                       ['REL', 'V']
# 135                               ['REL', 'V', 'PRON']
# 136                                              ['N']
# 137                               ['REL', 'V', 'PRON']
# 138                                              ['N']
# 139                                              ['N']
# 140                                              ['N']
# 141                                              ['N']
# 142                                  ['N', 'DET', 'N']
# 143                                      ['N', 'PRON']
# 144                                      ['COND', 'V']
# 145  ['REL', 'V', 'PRON', 'CONJ', 'REL', 'V', 'PRON...
# 146                                              ['N']
# 147                                              ['N']
# 148                                              ['N']
# 149                                              ['N']
# 150                                       ['N', 'ADJ']
# 151                                              ['N']
# 152                                              ['N']
# 153                                       ['N', 'ADJ']
# 154                                              ['N']
# 155                                              ['N']
# 156                                              ['N']
# 157                                              ['N']
# 158                                      ['N', 'PRON']
# 159                                              ['N']
# 160                                              ['N']
# 161                               ['REL', 'V', 'PRON']
# 162                                      ['N', 'PRON']
# 163                                              ['N']
# 164                                      ['N', 'PRON']
# 165                                              ['N']
# 166                                      ['COND', 'V']
# 167                                              ['N']
# 168                                              ['N']
# 169                                              ['N']
# 170                                      ['N', 'PRON']
# 171                                              ['N']
# 172                                      ['N', 'PRON']
# 173                          ['REL', 'V', 'P', 'PRON']
# 174                                              ['N']
# 175                                      ['N', 'PRON']
# 176               ['REL', 'V', 'SUB', 'V', 'DET', 'N']
# 177                                              ['N']
# 178                                              ['N']
# 179                                              ['N']
# 180                                      ['N', 'PRON']
# 181                                              ['N']
# 182                                      ['N', 'PRON']
# 183                                              ['N']
# 184                                      ['N', 'PRON']
# 185                  ['REL', 'V', 'PRON', 'P', 'PRON']
# 186                                              ['N']
# 187                                              ['N']
# 188                                      ['N', 'PRON']
# 189                                              ['N']
# 190                                              ['N']
# 191                                              ['N']
# 192                                              ['N']
# 193                          ['REL', 'V', 'PRON', 'P']
# 194                                              ['N']
# 195                                      ['N', 'PRON']
# 196                                      ['N', 'PRON']
# 197                                              ['N']
# 198                                              ['N']
# 199                               ['REL', 'V', 'PRON']
# 200                                              ['N']
# 201                                              ['N']
# 202                        ['INTG', 'DEM', 'REL', 'V']
# 203                                        ['N', 'PN']
# 204                                             ['PN']
# 205                                              ['N']
# 206                                              ['N']
# 207                                              ['N']
# 208                                              ['N']
# 209                                      ['N', 'PRON']
# 210                                             ['PN']
# 211                                              ['N']
# 212                                       ['REL', 'V']
# 213                                      ['N', 'PRON']
# 214                          ['PN', 'CONJ', 'N', 'PN']
# 215                                              ['N']
# 216                                             ['PN']
# 217                                      ['COND', 'V']
# 218                       ['COND', 'NEG', 'V', 'PRON']
# 219                               ['REL', 'V', 'PRON']
# 220                        ['PN', 'CONJ', 'N', 'PRON']
# 221                                       ['REL', 'V']
# 222                                       ['N', 'ADJ']
# 223                                       ['N', 'ADJ']
# 224                                              ['N']
# 225                   ['P', 'PN', 'CONJ', 'N', 'PRON']
# 226                                              ['N']
# 227                                            ['ADJ']
# 228                                             ['PN']
# 229                                             ['PN']
# 230                                              ['N']
# 231                                              ['N']
# 232                                       ['REL', 'V']
# 233                                  ['PN', 'N', 'PN']
# 234                          ['REL', 'P', 'N', 'PRON']
# 235                                       ['REL', 'V']
# 236                                       ['REL', 'V']
# 237                               ['REL', 'V', 'PRON']
# 238                                      ['N', 'PRON']
# 239                                              ['N']
# 240  ['COND', 'V', 'P', 'DET', 'N', 'CONJ', 'V', 'P...
# 241                               ['REL', 'V', 'PRON']
# 242                               ['REL', 'V', 'PRON']
# 243                                 ['REL', 'V', 'PN']
# 244                                             ['PN']
# 245                                             ['PN']
# 246                                       ['REL', 'V']
# 247                                ['N', 'DET', 'ADJ']
# 248                             ['REL', 'V', 'P', 'N']
# 249                                              ['N']
# 250                                             ['PN']
# 251                                              ['N']
# 252  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'PN']
# 253                                       ['REL', 'V']
# 254  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'PN']
# 255                               ['REL', 'V', 'PRON']
# 256                          ['REL', 'V', 'N', 'PRON']
# 257                                              ['N']
# 258                                              ['N']
# 259                                            ['ADJ']
# 260  ['REL', 'V', 'PRON', 'N', 'PRON', 'N', 'N', 'PN']
# 261                               ['REL', 'V', 'PRON']
# 262                                       ['REL', 'V']
# 263                          ['COND', 'V', 'DET', 'N']
# 264                                  ['N', 'DET', 'N']
# 265                                       ['DET', 'N']
# 266                                              ['N']
# 267                                              ['N']
# 268                                       ['REL', 'V']
# 269                                              ['N']
# 270               ['REL', 'V', 'PRON', 'P', 'N', 'PN']
# 271                                              ['N']
# 272                                              ['N']
# 273                                              ['N']
# 274  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'DET', ...
# 275                   ['REL', 'V', 'PRON', 'DET', 'N']
# 276                               ['REL', 'V', 'PRON']
# 277                              ['COND', 'V', 'PRON']
# 278                                      ['COND', 'V']
# 279                          ['N', 'DET', 'N', 'PRON']
# 280  ['REL', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DET...
# 281                               ['REL', 'V', 'PRON']
# 282                                              ['N']
# 283                               ['REL', 'V', 'PRON']
# 284                   ['REL', 'P', 'PRON', 'DET', 'N']
# 285                   ['REL', 'P', 'PRON', 'DET', 'N']
# 286                               ['REL', 'V', 'PRON']
# 287                                              ['N']
# 288                                              ['N']
# 289                                              ['N']
# 290                                              ['N']
# 291                                       ['REL', 'V']
# 292                              ['COND', 'V', 'PRON']
# 293                                       ['REL', 'V']
# 294                                              ['N']
# 295                                              ['N']
# 296                                              ['N']
# 297                                      ['N', 'PRON']
# 298                                              ['N']
# 299                          ['REL', 'P', 'N', 'PRON']
# 300                                              ['N']
# 301                                            ['ADJ']
# 302                                              ['N']
# 303                               ['REL', 'V', 'PRON']
# 304                    ['COND', 'P', 'N', 'PRON', 'N']
# 305                                  ['N', 'DET', 'N']
# 306                                              ['N']
# 307                               ['REL', 'V', 'PRON']
# 308                                      ['N', 'PRON']
# 309                                        ['N', 'PN']
# 310                          ['REL', 'P', 'N', 'PRON']
# 311                               ['REL', 'V', 'PRON']
# 312                                       ['REL', 'V']
# 313                                  ['N', 'DET', 'N']
# 314                          ['N', 'CONJ', 'DET', 'N']
# 315                               ['REL', 'V', 'PRON']
# 316  ['REL', 'V', 'PRON', 'N', 'PRON', 'ACC', 'PRON...
# 317                                              ['N']
# 318              ['REL', 'V', 'PRON', 'P', 'DET', 'N']
# 319                           ['V', 'PRON', 'P', 'PN']
# 320                                            ['DET']
# 321                                       ['DET', 'N']
# 322           ['VOC', 'N', 'PRON', 'REL', 'V', 'PRON']
# 323  ['CONJ', 'REL', 'V', 'PRON', 'CONJ', 'V', 'PRO...
# 324                                       ['DET', 'N']
# 325  ['REL', 'V', 'PRON', 'CONJ', 'P', 'N', 'PRON',...
# 326                     ['N', 'NEG', 'V', 'N', 'PRON']
# 327                                       ['REL', 'V']
# 328                                              ['N']
# 329                                              ['N']
# 330                             ['P', 'DET', 'N', 'V']
# 331                                              ['N']
# 332                                       ['REL', 'V']
# 333                                       ['DET', 'N']
# 334                                      ['DET', 'PN']
# 335                                       ['DET', 'N']
# 336                                              ['N']
# 337                                              ['N']
# 338                          ['REL', 'P', 'N', 'PRON']
# 339                                      ['N', 'PRON']
# 340                                       ['REL', 'V']
# 341                                       ['DET', 'N']
# 342  ['COND', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DE...
# 343                                      ['V', 'PRON']
# 344  ['COND', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'P'...
# 345                                              ['N']
# 346                                         ['N', 'V']
# 347                                              ['N']
# 348   ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'N']
# 349                                              ['N']
# 350                                              ['N']
# 351  ['REL', 'V', 'PRON', 'N', 'PRON', 'CONJ', 'V',...
# 352                                              ['N']
# 353                            ['P', 'N', 'PRON', 'V']
# 354                                              ['V']
# 355                                      ['V', 'PRON']
# 356                                              ['N']
# 357              ['DET', 'N', 'CONJ', 'N', 'DET', 'N']
# 358                          ['P', 'REL', 'V', 'PRON']
# 359                                              ['N']
# 360                                       ['DET', 'N']
# 361                                              ['N']
# 362                                              ['V']
# 363                                       ['DET', 'N']
# 364                                       ['REL', 'V']
# 365                                       ['DET', 'N']
# 366                                       ['DET', 'N']
# 367                                       ['DET', 'N']
# 368                          ['ADJ', 'P', 'N', 'PRON']
# 369                                              ['N']
# 370                                              ['N']
# 371                                       ['REL', 'V']
# 372                                       ['REL', 'V']
# 373                                       ['RES', 'N']
# 374                        ['REL', 'NEG', 'V', 'PRON']
# 375                        ['REL', 'NEG', 'V', 'PRON']
# 376                                              ['N']
# 377                   ['REL', 'V', 'PRON', 'DET', 'N']
# 378                          ['V', 'PRON', 'DET', 'N']
# 379     ['PRON', 'P', 'DET', 'N', 'PRON', 'V', 'PRON']
# 380                                       ['DET', 'N']
# 381                                       ['DET', 'N']
# 382  ['REL', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DET...
# 383                                       ['DET', 'N']
# 384                                              ['N']
# 385                 ['PRON', 'V', 'PRON', 'N', 'PRON']
# 386                                      ['N', 'PRON']
# 387                                  ['REL', 'V', 'P']
# 388                                              ['N']
# 389                                              ['N']
# 390                                              ['N']
# 391                                       ['DET', 'N']
# 392                                       ['REL', 'V']
# 393                                              ['N']
# 394                                              ['V']
# 395                                            ['ADJ']
# 396                                            ['ADJ']
# 397                                            ['ADJ']
# 398                                            ['ADJ']
# 399                                              ['N']
# 400                            ['N', 'P', 'N', 'PRON']
# 401                                              ['N']
# 402                                      ['N', 'PRON']
# 403                                       ['DET', 'N']
# 404                                              ['N']
# 405                                              ['N']
# 406                          ['N', 'CONJ', 'NEG', 'N']
# 407                                       ['DET', 'N']
# 408                                      ['N', 'PRON']
# 409                                       ['DET', 'N']
# 410                                      ['PRON', 'N']
# 411                                       ['DET', 'N']
# 412                                    ['V', 'P', 'N']
# 413             ['REL', 'T', 'V', 'PRON', 'P', 'PRON']
# 414                                 ['V', 'PRON', 'N']
# 415                                              ['V']
# 416                                 ['N', 'N', 'PRON']
# 417                               ['NEG', 'V', 'PRON']
# 418                                              ['N']
# 419                                              ['N']
# 420  ['COND', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DE...
# 421                                      ['COND', 'V']
# 422                                              ['N']
# 423                                        ['N', 'PN']
# 424                                              ['N']
# 425                                              ['N']
# 426                                              ['N']
# 427                                       ['REL', 'V']
# 428                                              ['N']
# 429                                              ['N']
# 430                   ['DET', 'N', 'CONJ', 'DET', 'N']
# 431                                      ['N', 'PRON']
# 432                                      ['N', 'PRON']
# 433                         ['N', 'PRON', 'N', 'PRON']
# 434                                       ['DET', 'N']
# 435                         ['N', 'PRON', 'N', 'PRON']
# 436                   ['DET', 'N', 'CONJ', 'DET', 'N']
# 437                                      ['N', 'PRON']
# 438                                              ['N']
# 439                     ['DET', 'N', 'P', 'N', 'PRON']
# 440                                       ['DET', 'N']

# %%
patterns10Juz = patterns10Juz.drop_duplicates(subset=None, keep='first', inplace=False)
print(len(patterns10Juz))
patterns10Juz
# Out:
# 93
#                                                pattern
# 0                                                ['N']
# 2                                              ['ADJ']
# 5                                         ['DET', 'N']
# 8                                         ['REL', 'V']
# 10                                  ['REL', 'V', 'PN']
# 11                    ['REL', 'V', 'PRON', 'DET', 'N']
# 14            ['REL', 'V', 'PRON', 'PRON', 'DET', 'N']
# 15                                       ['N', 'PRON']
# 18                                ['REL', 'V', 'PRON']
# 22                   ['REL', 'V', 'P', 'N', 'PN', 'N']
# 24                      ['REL', 'T', 'V', 'PRON', 'N']
# 26              ['COND', 'V', 'DET', 'N', 'CONJ', 'V']
# 40                         ['P', 'N', 'P', 'DET', 'N']
# 50                                       ['COND', 'V']
# 52   ['REL', 'V', 'PRON', 'DET', 'N', 'P', 'DET', 'N']
# 53               ['REL', 'V', 'PRON', 'P', 'DET', 'N']
# 56                                   ['N', 'DET', 'N']
# 61                                   ['V', 'DET', 'N']
# 80                               ['COND', 'V', 'PRON']
# 85                           ['REL', 'P', 'N', 'PRON']
# 86                     ['COND', 'V', 'P', 'PRON', 'N']
# 87                        ['REL', 'V', 'PRON', 'PRON']
# 88                                  ['COND', 'V', 'N']
# 90                          ['COND', 'V', 'P', 'PRON']
# 95                               ['V', 'PRON', 'PRON']
# 108  ['REL', 'NEG', 'V', 'N', 'PRON', 'N', 'DET', '...
# 114                                            ['REL']
# 121                          ['REL', 'V', 'N', 'PRON']
# 122                                        ['N', 'PN']
# 145  ['REL', 'V', 'PRON', 'CONJ', 'REL', 'V', 'PRON...
# 150                                       ['N', 'ADJ']
# 173                          ['REL', 'V', 'P', 'PRON']
# 176               ['REL', 'V', 'SUB', 'V', 'DET', 'N']
# 185                  ['REL', 'V', 'PRON', 'P', 'PRON']
# 193                          ['REL', 'V', 'PRON', 'P']
# 202                        ['INTG', 'DEM', 'REL', 'V']
# 204                                             ['PN']
# 214                          ['PN', 'CONJ', 'N', 'PN']
# 218                       ['COND', 'NEG', 'V', 'PRON']
# 220                        ['PN', 'CONJ', 'N', 'PRON']
# 225                   ['P', 'PN', 'CONJ', 'N', 'PRON']
# 233                                  ['PN', 'N', 'PN']
# 240  ['COND', 'V', 'P', 'DET', 'N', 'CONJ', 'V', 'P...
# 247                                ['N', 'DET', 'ADJ']
# 248                             ['REL', 'V', 'P', 'N']
# 252  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'PN']
# 260  ['REL', 'V', 'PRON', 'N', 'PRON', 'N', 'N', 'PN']
# 263                          ['COND', 'V', 'DET', 'N']
# 270               ['REL', 'V', 'PRON', 'P', 'N', 'PN']
# 274  ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'DET', ...
# 279                          ['N', 'DET', 'N', 'PRON']
# 280  ['REL', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DET...
# 284                   ['REL', 'P', 'PRON', 'DET', 'N']
# 304                    ['COND', 'P', 'N', 'PRON', 'N']
# 314                          ['N', 'CONJ', 'DET', 'N']
# 316  ['REL', 'V', 'PRON', 'N', 'PRON', 'ACC', 'PRON...
# 319                           ['V', 'PRON', 'P', 'PN']
# 320                                            ['DET']
# 322           ['VOC', 'N', 'PRON', 'REL', 'V', 'PRON']
# 323  ['CONJ', 'REL', 'V', 'PRON', 'CONJ', 'V', 'PRO...
# 325  ['REL', 'V', 'PRON', 'CONJ', 'P', 'N', 'PRON',...
# 326                     ['N', 'NEG', 'V', 'N', 'PRON']
# 330                             ['P', 'DET', 'N', 'V']
# 334                                      ['DET', 'PN']
# 342  ['COND', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DE...
# 343                                      ['V', 'PRON']
# 344  ['COND', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'P'...
# 346                                         ['N', 'V']
# 348   ['REL', 'V', 'PRON', 'N', 'PRON', 'P', 'N', 'N']
# 351  ['REL', 'V', 'PRON', 'N', 'PRON', 'CONJ', 'V',...
# 353                            ['P', 'N', 'PRON', 'V']
# 354                                              ['V']
# 357              ['DET', 'N', 'CONJ', 'N', 'DET', 'N']
# 358                          ['P', 'REL', 'V', 'PRON']
# 368                          ['ADJ', 'P', 'N', 'PRON']
# 373                                       ['RES', 'N']
# 374                        ['REL', 'NEG', 'V', 'PRON']
# 378                          ['V', 'PRON', 'DET', 'N']
# 379     ['PRON', 'P', 'DET', 'N', 'PRON', 'V', 'PRON']
# 382  ['REL', 'V', 'PRON', 'CONJ', 'V', 'PRON', 'DET...
# 385                 ['PRON', 'V', 'PRON', 'N', 'PRON']
# 387                                  ['REL', 'V', 'P']
# 400                            ['N', 'P', 'N', 'PRON']
# 406                          ['N', 'CONJ', 'NEG', 'N']
# 410                                      ['PRON', 'N']
# 412                                    ['V', 'P', 'N']
# 413             ['REL', 'T', 'V', 'PRON', 'P', 'PRON']
# 414                                 ['V', 'PRON', 'N']
# 416                                 ['N', 'N', 'PRON']
# 417                               ['NEG', 'V', 'PRON']
# 430                   ['DET', 'N', 'CONJ', 'DET', 'N']
# 433                         ['N', 'PRON', 'N', 'PRON']
# 439                     ['DET', 'N', 'P', 'N', 'PRON']

# %% [markdown]
# ## Set Human Entity Rule

# %%
# Import data
quranicArab = pd.read_excel('./Output/quranic-corpus-morphology-0.4-with-arab-juz-2.xlsx', encoding='utf8')
pd.set_option('display.max_rows', 999999) # Untuk menampilkan semua data sekaligus

# %%
# Prepare data
def convertAndGroupToArray(data):
    
    ayats = [[]]

    for index, row in data.iterrows():
        location = row['LOCATION']
        ayat = location.split(':')[1]
        data.at[index, 'LOCATION'] = ayat

    length = len(data)
    i = 0
    data.at[0, 'LOCATION'] = 0
    
    for index, row in data.iterrows():
        
        # tokenizing location
        if index < length-1:
            currentLocation = row['LOCATION']
            nextLocation = data.at[index+1, 'LOCATION']

            if index == length-2 or currentLocation != nextLocation:
                i = i+1
                ayats.append([])
            
            data.at[index, 'LOCATION'] = i
            
            words = {
                'OPEN TAG' : '',
                'AYAT' : int(row['LOCATION']),
                'ARAB' : row['ARAB'],
                'TAG' : row['TAG'],
                'CLOSE TAG' : ''
            }
            
            ayats[i].append(words)
    
    return ayats
     
ayats = convertAndGroupToArray(quranicArab)

# %%
# Rule based logic
def findHumanEntity(ayats):
    
    ayatIndex = 0
    entityIndex = 0
    for ayat in ayats:
        for pattern in patterns10Juz:
            patternLength = len(pattern)
            for wordIndex in range(len(ayat) - patternLength):
                # Get set of words based on the pattern length
                wordTagsSet = []
                for wordOfSetIndex in range((patternLength)):
                    wordTagsSet.append(ayat[wordIndex+wordOfSetIndex]['TAG'])
                if str(wordTagsSet) == str(pattern):
                    ayat[wordIndex]['OPEN TAG'] += str(entityIndex) + '('
                    ayat[wordIndex+patternLength]['CLOSE TAG'] += str(entityIndex) + ')'
                    entityIndex += 1
        ayatIndex += 1
                
findHumanEntity(ayats)

# %%
ayatDF = pd.DataFrame({'AYAT': [], 'OPEN TAG': [], 'ARAB': [], 'TAG': [], 'CLOSE TAG': []});

ayatCollections = []
openTagCollections = []
arabCollections = []
tagCollections = []
closeTagCollections = []

for ayat in ayats:
    for word in ayat:
        ayatDF = ayatDF.append({'AYAT': word['AYAT'], 'OPEN TAG': word['OPEN TAG'], 'ARAB': word['ARAB'], 'TAG': word['TAG'], 'CLOSE TAG': word['CLOSE TAG']}, ignore_index=True)
        
ayatDF
# Out:
#        AYAT                                           OPEN TAG  \
# 0       1.0
# 1       1.0                                     5(20(((((5(20(
# 2       1.0                                   13(25(((((13(25(
# 3       1.0                                           29(((29(
# 4       1.0
# 5       1.0                                   14(26(((((14(26(
# 6       1.0                                           30(((30(
# 7       1.0
# 8       1.0                                     6(18(((((6(18(
# 9       1.0
# 10      1.0
# 11      1.0                                   17(31(((((17(31(
# 12      1.0
# 13      1.0              0(1(11(21(34((((((((((((0(1(11(21(34(
# 14      1.0                                     7(19(((((7(19(
# 15      1.0
# 16      1.0
# 17      1.0
# 18      1.0                                             8(((8(
# 19      1.0
# 20      1.0                                             3(((3(
# 21      1.0                           15(24(27(((((((15(24(27(
# 22      1.0                                   23(32(((((23(32(
# 23      1.0
# 24      1.0                                   16(28(((((16(28(
# 25      1.0                                   12(33(((((12(33(
# 26      1.0                                             9(((9(
# 27      1.0                               2(4(22(((((((2(4(22(
# 28      1.0                                           10(((10(
# 29      1.0
# 30      1.0
# 251     6.0                     240(242(245(((((((240(242(245(
# 252     6.0                               238(243(((((238(243(
# 253     6.0
# 254     6.0                               241(244(((((241(244(
# 255     6.0
# 256     6.0
# 257     6.0
# 258     6.0                                         239(((239(
# 259     6.0
# 260     6.0
# 261     6.0
# 262     7.0                                         261(((261(
# 263     7.0
# 264     7.0
# 265     7.0                               259(262(((((259(262(
# 266     7.0                     248(254(263(((((((248(254(263(
# 267     7.0                                         252(((252(
# 268     7.0                               255(264(((((255(264(
# 269     7.0
# 270     7.0
# 271     7.0                     249(256(260(((((((249(256(260(
# 272     7.0
# 273     7.0                               253(258(((((253(258(
# 274     7.0                                         265(((265(
# 275     7.0
# 276     7.0
# 277     7.0                               250(257(((((250(257(
# 278     7.0
# 279     7.0                                         251(((251(
# 280     7.0
# 281     7.0
# 282     7.0                                         246(((246(
# 283     7.0                                         266(((266(
# 284     7.0
# 285     7.0                                         247(((247(
# 286     7.0
# 287     7.0                                         267(((267(
# 288     7.0
# 289     8.0                                         284(((284(
# 290     8.0
# 291     8.0
# 292     8.0                               273(285(((((273(285(
# 293     8.0                               271(279(((((271(279(
# 294     8.0
# 295     8.0
# 296     8.0                                         272(((272(
# 297     8.0                               277(286(((((277(286(
# 298     8.0
# 299     8.0
# 300     8.0                               274(282(((((274(282(
# 301     8.0                               281(287(((((281(287(
# 302     8.0                                         275(((275(
# 303     8.0                                         269(((269(
# 304     8.0
# 305     8.0
# 306     8.0
# 307     8.0
# 308     8.0                     276(283(291(((((((276(283(291(
# 309     8.0                               270(288(((((270(288(
# 310     8.0
# 311     8.0                               278(289(((((278(289(
# 312     8.0
# 313     8.0
# 314     8.0
# 315     8.0                                         268(((268(
# 316     8.0
# 317     8.0                                         290(((290(
# 318     8.0
# 319     8.0                                         280(((280(
# 320     8.0
# 321     9.0
# 322     9.0
# 323     9.0
# 324     9.0                               308(327(((((308(327(
# 325     9.0                               296(315(((((296(315(
# 326     9.0
# 327     9.0
# 328     9.0                                         297(((297(
# 329     9.0                               312(328(((((312(328(
# 330     9.0
# 331     9.0
# 332     9.0                               309(325(((((309(325(
# 333     9.0                               324(329(((((324(329(
# 334     9.0                                         310(((310(
# 335     9.0                                         294(((294(
# 336     9.0
# 337     9.0
# 338     9.0
# 339     9.0                               298(316(((((298(316(
# 340     9.0
# 341     9.0
# 342     9.0                     295(299(317(((((((295(299(317(
# 343     9.0                                         305(((305(
# 344     9.0                               313(330(((((313(330(
# 345     9.0
# 346     9.0
# 347     9.0
# 348     9.0
# 349     9.0
# 350     9.0
# 351     9.0                                         300(((300(
# 352     9.0
# 353     9.0                               311(326(((((311(326(
# 354     9.0                                         331(((331(
# 355     9.0
# 356     9.0                                         306(((306(
# 357     9.0                                         332(((332(
# 358     9.0
# 359     9.0  292(293(307(321(334(((((((((((292(293(307(321(...
# 360     9.0                               301(318(((((301(318(
# 361     9.0
# 362     9.0
# 363     9.0
# 364     9.0
# 365     9.0
# 366     9.0                     302(319(322(((((((302(319(322(
# 367     9.0
# 368     9.0
# 369     9.0
# 370     9.0                     303(320(323(((((((303(320(323(
# 371     9.0
# 372     9.0
# 373     9.0
# 374     9.0
# 375     9.0                                         304(((304(
# 376     9.0                               314(333(((((314(333(
# 377     9.0
# 378     9.0
# 379     9.0
# 380     9.0
# 381     9.0
# 382     9.0
# 383     9.0
# 384    10.0
# 385    10.0
# 386    10.0
# 387    10.0                               336(347(((((336(347(
# 388    10.0
# 389    10.0
# 390    10.0                                         342(((342(
# 391    10.0                                         359(((359(
# 392    10.0
# 393    10.0
# 394    10.0                                         337(((337(
# 395    10.0
# 396    10.0                                         343(((343(
# 397    10.0                               346(360(((((346(360(
# 398    10.0
# 399    10.0
# 400    10.0                               338(348(((((338(348(
# 401    10.0
# 402    10.0
# 403    10.0                     339(349(358(((((((339(349(358(
# 404    10.0
# 405    10.0                     344(355(356(((((((344(355(356(
# 406    10.0                               354(361(((((354(361(
# 407    10.0
# 408    10.0                               345(357(((((345(357(
# 409    10.0                                         362(((362(
# 410    10.0
# 411    10.0                               340(350(((((340(350(
# 412    10.0
# 413    10.0                               352(353(((((352(353(
# 414    10.0                                         335(((335(
# 415    10.0                               341(351(((((341(351(
# 416    10.0
# 417    10.0
# 418    11.0
# 419    11.0
# 420    11.0                     363(367(370(((((((363(367(370(
# 421    11.0
# 422    11.0
# 423    11.0                               364(368(((((364(368(
# 424    11.0
# 425    11.0
# 426    11.0                               365(369(((((365(369(
# 427    11.0
# 428    11.0
# 429    11.0
# 430    11.0
# 431    11.0
# 432    11.0                                         366(((366(
# 433    11.0
# 434    12.0
# 435    12.0
# 436    12.0                                         385(((385(
# 437    12.0                     371(372(380(((((((371(372(380(
# 438    12.0                               374(378(((((374(378(
# 439    12.0
# 440    12.0                               375(379(((((375(379(
# 441    12.0
# 442    12.0
# 443    12.0                     376(382(383(((((((376(382(383(
# 444    12.0                               381(386(((((381(386(
# 445    12.0
# 446    12.0                               377(384(((((377(384(
# 447    12.0                                         387(((387(
# 448    12.0
# 449    12.0                                         373(((373(
# 450    12.0
# 451    12.0
# 452    13.0                                         399(((399(
# 453    13.0
# 454    13.0
# 455    13.0                               392(397(((((392(397(
# 456    13.0
# 457    13.0
# 458    13.0  388(390(394(396(398(((((((((((388(390(394(396(...
# 459    13.0                               391(393(((((391(393(
# 460    13.0
# 461    13.0                               395(400(((((395(400(
# 462    13.0                                         389(((389(
# 463    13.0                                         401(((401(
# 464    13.0
# 465    13.0                                         402(((402(
# 466    13.0
# 467    13.0
# 468    13.0
# 469    13.0
# 470    14.0
# 471    14.0
# 472    14.0
# 473    14.0                                         404(((404(
# 474    14.0
# 475    14.0
# 476    14.0                                         403(((403(
# 477    14.0                                         422(((422(
# 478    14.0
# 479    14.0                     406(414(417(((((((406(414(417(
# 480    14.0                               411(423(((((411(423(
# 481    14.0
# 482    14.0                               407(418(((((407(418(
# 483    14.0                                         424(((424(
# 484    14.0
# 485    14.0                                         425(((425(
# 486    14.0
# 487    14.0                     408(415(419(((((((408(415(419(
# 488    14.0                               412(426(((((412(426(
# 489    14.0
# 490    14.0                     409(416(420(((((((409(416(420(
# 491    14.0                               413(427(((((413(427(
# 492    14.0
# 493    14.0                               410(421(((((410(421(
# 494    14.0                                         428(((428(
# 495    14.0
# 496    14.0                                         405(((405(
# 497    14.0
# 498    15.0                                         439(((439(
# 499    15.0                               435(438(((((435(438(
# 500    15.0
# 501    15.0                     430(431(436(((((((430(431(436(
# 502    15.0                                         433(((433(
# 503    15.0                               434(440(((((434(440(
# 504    15.0                               432(437(((((432(437(
# 505    15.0
# 506    15.0
# 507    15.0
# 508    15.0
# 509    15.0                                         429(((429(
# 510    15.0
# 511    15.0
# 512    15.0
# 513    15.0
# 514    15.0
# 515    16.0                                         444(((444(
# 516    16.0
# 517    16.0
# 518    16.0                                         442(((442(
# 519    16.0                               441(445(((((441(445(
# 520    16.0
# 521    16.0                               443(446(((((443(446(
# 522    16.0
# 523    16.0
# 524    16.0                                         447(((447(
# 525    16.0
# 526    16.0
# 527    16.0
# 528    16.0
# 529    17.0                                         469(((469(
# 530    17.0
# 531    17.0                               457(465(((((457(465(
# 532    17.0                                         448(((448(
# 533    17.0
# 534    17.0                               458(466(((((458(466(
# 535    17.0                                         449(((449(
# 536    17.0
# 537    17.0                               461(470(((((461(470(
# 538    17.0                                         450(((450(
# 539    17.0
# 540    17.0                     452(460(463(((((((452(460(463(
# 541    17.0                               453(462(((((453(462(
# 542    17.0                               459(467(((((459(467(
# 543    17.0                                         471(((471(
# 544    17.0
# 545    17.0                                         454(((454(
# 546    17.0
# 547    17.0
# 548    17.0                                         472(((472(
# 549    17.0
# 550    17.0
# 551    17.0
# 552    17.0                                         455(((455(
# 553    17.0
# 554    17.0
# 555    17.0
# 556    17.0                               464(468(((((464(468(
# 557    17.0                                         456(((456(
# 558    17.0                                         473(((473(
# 559    17.0
# 560    17.0
# 561    17.0                                         451(((451(
# 562    17.0
# 563    18.0                                         481(((481(
# 564    18.0
# 565    18.0                     474(477(497(((((((474(477(497(
# 566    18.0                               482(492(((((482(492(
# 567    18.0
# 568    18.0  475(478(498(502(513(((((((((((475(478(498(502(...
# 569    18.0                               483(493(((((483(493(
# 570    18.0
# 571    18.0
# 572    18.0                     488(503(504(((((((488(503(504(
# 573    18.0                               501(508(((((501(508(
# 574    18.0
# 575    18.0                               489(505(((((489(505(
# 576    18.0                                         509(((509(
# 577    18.0
# 578    18.0                                         510(((510(
# 579    18.0           476(479(487(499(((((((((476(479(487(499(
# 580    18.0                     484(494(500(((((((484(494(500(
# 581    18.0
# 582    18.0
# 583    18.0
# 584    18.0                               490(506(((((490(506(
# 585    18.0                                         511(((511(
# 586    18.0
# 587    18.0                               491(507(((((491(507(
# 588    18.0                                         512(((512(
# 589    18.0
# 590    18.0                               485(495(((((485(495(
# 591    18.0
# 592    18.0                                         480(((480(
# 593    18.0
# 594    18.0                               486(496(((((486(496(
# 595    18.0
# 596    18.0
# 597    19.0                                         526(((526(
# 598    19.0
# 599    19.0                     514(515(524(((((((514(515(524(
# 600    19.0                               516(521(((((516(521(
# 601    19.0
# 602    19.0
# 603    19.0                               517(522(((((517(522(
# 604    19.0
# 605    19.0
# 606    19.0                               518(523(((((518(523(
# 607    19.0
# 608    19.0
# 609    19.0
# 610    19.0                                         519(((519(
# 611    19.0
# 612    19.0
# 613    19.0
# 614    19.0
# 615    19.0                               520(525(((((520(525(
# 616    19.0                                         527(((527(
# 617    19.0
# 618    20.0                                         531(((531(
# 619    20.0
# 620    20.0                     528(529(541(((((((528(529(541(
# 621    20.0                               532(539(((((532(539(
# 622    20.0
# 623    20.0
# 624    20.0                               533(540(((((533(540(
# 625    20.0
# 626    20.0
# 627    20.0                                         534(((534(
# 628    20.0                                         543(((543(
# 629    20.0
# 630    20.0
# 631    20.0                                         535(((535(
# 632    20.0                               538(544(((((538(544(
# 633    20.0                                         530(((530(
# 634    20.0
# 635    20.0                               536(542(((((536(542(
# 636    20.0                                         545(((545(
# 637    20.0
# 638    20.0                                         537(((537(
# 639    20.0
# 640    21.0                                         549(((549(
# 641    21.0                                         550(((550(
# 642    21.0
# 643    21.0
# 644    21.0
# 645    21.0                                         546(((546(
# 646    21.0
# 647    21.0
# 648    21.0                               547(548(((((547(548(
# 649    21.0                                         551(((551(
# 650    21.0
# 651    21.0
# 652    21.0
# 653    21.0
# 654    22.0
# 655    22.0
# 656    22.0                               556(558(((((556(558(
# 657    22.0                                         554(((554(
# 658    22.0                               553(559(((((553(559(
# 659    22.0                                         552(((552(
# 660    22.0
# 661    22.0                                         560(((560(
# 662    22.0
# 663    22.0
# 664    22.0                               555(557(((((555(557(
# 665    22.0                                         561(((561(
# 666    22.0
# 667    23.0                                         570(((570(
# 668    23.0
# 669    23.0
# 670    23.0                               566(622(((((566(622(
# 671    23.0                     579(604(609(((((((579(604(609(
# 672    23.0                               598(623(((((598(623(
# 673    23.0
# 674    23.0                     569(580(610(((((((569(580(610(
# 675    23.0                                         624(((624(
# 676    23.0
# 677    23.0                               567(625(((((567(625(
# 678    23.0                     581(605(611(((((((581(605(611(
# 679    23.0                               599(626(((((599(626(
# 680    23.0
# 681    23.0                     582(606(612(((((((582(606(612(
# 682    23.0                               600(627(((((600(627(
# 683    23.0
# 684    23.0                               583(613(((((583(613(
# 685    23.0                                         628(((628(
# 686    23.0                     562(572(595(((((((562(572(595(
# 687    23.0                                         573(((573(
# 688    23.0
# 689    23.0                               584(614(((((584(614(
# 690    23.0                                         629(((629(
# 691    23.0
# 692    23.0                               563(596(((((563(596(
# 693    23.0                               574(594(((((574(594(
# 694    23.0                               585(615(((((585(615(
# 695    23.0                                         630(((630(
# 696    23.0
# 697    23.0                     564(578(597(((((((564(578(597(
# 698    23.0                                         575(((575(
# 699    23.0                                         565(((565(
# 700    23.0
# 701    23.0                               586(616(((((586(616(
# 702    23.0                                         631(((631(
# 703    23.0
# 704    23.0                                         632(((632(
# 705    23.0
# 706    23.0                                         576(((576(
# 707    23.0
# 708    23.0
# 709    23.0                               587(617(((((587(617(
# 710    23.0                                         633(((633(
# 711    23.0
# 712    23.0                               593(634(((((593(634(
# 713    23.0
# 714    23.0
# 715    23.0                                         577(((577(
# 716    23.0
# 717    23.0
# 718    23.0
# 719    23.0                                         635(((635(
# 720    23.0                                         636(((636(
# 721    23.0
# 722    23.0                               568(637(((((568(637(
# 723    23.0                     588(607(618(((((((588(607(618(
# 724    23.0                               601(638(((((601(638(
# 725    23.0
# ...
# 4152              هُ  PRON                                      3590)))3590)
# 4153             ٱلْ   DET                                      3602)))3602)
# 4154     مَلَٰئِكَةُ     N                                      3595)))3595)
# 4155           إِنَّ   ACC              3606)3609)3619)))))))3606)3609)3619)
# 4156             فِى     P
# 4157         ذَٰلِكَ   DEM
# 4158              لَ  EMPH
# 4159          اٰيَةً     N
# 4160             لَّ     P                                      3620)))3620)
# 4161            كُمْ  PRON
# 4162             إِن  COND
# 4163             كُن     V
# 4164             تُم  PRON                          3591)3604)))))3591)3604)
# 4165    مُّؤْمِنِينَ     N
# 4166              فَ   REM                                      3675)))3675)
# 4167          لَمَّا     T
# 4168          فَصَلَ     V
# 4169        طَالُوتُ    PN                                      3637)))3637)
# 4170              بِ     P                                      3627)))3627)
# 4171             ٱلْ   DET
# 4172         جُنُودِ     N                                      3656)))3656)
# 4173           قَالَ     V                          3674)3676)))))3674)3676)
# 4174           إِنَّ   ACC              3623)3638)3654)))))))3623)3638)3654)
# 4175         ٱللَّهَ    PN
# 4176       مُبْتَلِي     N                                      3628)))3628)
# 4177             كُم  PRON                                      3677)))3677)
# 4178              بِ     P                                      3658)))3658)
# 4179          نَهَرٍ     N
# 4180              فَ   REM                                      3678)))3678)
# 4181             مَن  COND
# 4182          شَرِبَ     V
# 4183            مِنْ     P                          3639)3672)))))3639)3672)
# 4184              هُ  PRON
# 4185              فَ  RSLT                                      3688)))3688)
# 4186          لَيْسَ     V
# 4187           مِنِّ     P                                      3640)))3640)
# 4188               ى  PRON
# 4189              وَ  CONJ
# 4190             مَن  COND
# 4191           لَّمْ   NEG
# 4192        يَطْعَمْ     V
# 4193              هُ  PRON                                      3641)))3641)
# 4194              فَ  RSLT              3636)3663)3689)))))))3636)3663)3689)
# 4195           إِنَّ   ACC
# 4196             هُ,  PRON
# 4197           مِنِّ     P
# 4198               ى  PRON
# 4199          إِلَّا   EXP
# 4200            مَنِ   REL
# 4201       ٱغْتَرَفَ     V                                      3669)))3669)
# 4202        غُرْفَةً     N                          3624)3642)))))3624)3642)
# 4203              بِ     P                                      3679)))3679)
# 4204            يَدِ     N
# 4205             هِ.  PRON                                      3680)))3680)
# 4206              فَ  CONJ                          3635)3659)))))3635)3659)
# 4207          شَرِبُ     V
# 4208              وا  PRON                                      3643)))3643)
# 4209            مِنْ     P                                      3664)))3664)
# 4210              هُ  PRON
# 4211          إِلَّا   EXP
# 4212        قَلِيلًا     N
# 4213           مِّنْ     P                                      3681)))3681)
# 4214            هُمْ  PRON
# 4215              فَ   REM
# 4216          لَمَّا     T
# 4217         جَاوَزَ     V
# 4218             هُ,  PRON                                      3644)))3644)
# 4219            هُوَ  PRON                                      3665)))3665)
